# %% [markdown]
# # 其他工具：Grab、PyQuery
#
#
# * 利用 Grab 套件的存取 HTML 資源
# * 利用 PyQuery 套件的解析 HTML 格式

# %% [markdown]
# ## 作業目標
#
# 將之前用 requests + beatifulsoup 實作的方式，改寫成 grab + pyquery，並且比較有哪些地方不同。

# %% [markdown]
# ## requests + BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup

r = requests.get('https://google.com')
soup = BeautifulSoup(r.text, 'lxml')
print(type(soup.title), soup.title.text)
# Out:
# <class 'bs4.element.Tag'> Google

# %% [markdown]
# ## Grab + PyQuery

# %%
# !pip install grab pyquery
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting grab
#   Downloading grab-0.6.41.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 5.5 MB/s
# Collecting pyquery
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Collecting weblib>=0.1.28
#   Downloading weblib-0.1.30.tar.gz (30 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from grab) (1.15.0)
# Collecting user_agent
#   Downloading user_agent-0.1.10.tar.gz (20 kB)
# Collecting selection
#   Downloading selection-0.0.14.tar.gz (4.5 kB)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.7/dist-packages (from grab) (0.7.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from grab) (4.2.6)
# Collecting pycurl<7.43.0.2
#   Downloading pycurl-7.43.0.1.tar.gz (195 kB)
#      |████████████████████████████████| 195 kB 56.4 MB/s
# Collecting pytils
#   Downloading pytils-0.4.1.tar.gz (99 kB)
#      |████████████████████████████████| 99 kB 8.4 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# Collecting cssselect>0.7.9
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Building wheels for collected packages: grab, pycurl, weblib, pytils, selection, user-agent
#   Building wheel for grab (setup.py) ... done
#   Created wheel for grab: filename=grab-0.6.41-py3-none-any.whl size=84708 sha256=ae5e941d8be6353362387acabee8ba747060d7bb57fec98f2911901f8a35b7b3
#   Stored in directory: /root/.cache/pip/wheels/42/37/49/63cd1902086963e8a9e169ca60d89326c9e24adb6ffcfd5d06
#   Building wheel for pycurl (setup.py) ... done
#   Created wheel for pycurl: filename=pycurl-7.43.0.1-cp37-cp37m-linux_x86_64.whl size=256561 sha256=c944011524bd6f4fb5b2e6cc96a7fc50c2fbdf151e5b3ad513eaff52adf59677
#   Stored in directory: /root/.cache/pip/wheels/d5/ff/5a/2a716fe10774bf66a5163a9ab95c997f596c29ddf582486ea3
#   Building wheel for weblib (setup.py) ... done
#   Created wheel for weblib: filename=weblib-0.1.30-py3-none-any.whl size=40171 sha256=c84018bcd4f83dbc13867b3d21599c3ef0fe39805d8fb58cb5218af56803bf46
#   Stored in directory: /root/.cache/pip/wheels/24/d5/f3/8318d559709fd7ed73143b733bb313124203a52ac8d1eb80cb
#   Building wheel for pytils (PEP 517) ... done
#   Created wheel for pytils: filename=pytils-0.4.1-py3-none-any.whl size=32525 sha256=fd95c8b4f1f7e9e24f8ef57a834370edd0b3db25338c5b54ea823f6b7f743c7d
#   Stored in directory: /root/.cache/pip/wheels/19/44/3e/fed804565a6a9150b66cdf6312f1a0577c0a54c429c4911423
#   Building wheel for selection (setup.py) ... done
#   Created wheel for selection: filename=selection-0.0.14-py3-none-any.whl size=5372 sha256=cf477f7d707f966191e415ab5c2ee368683542d9a377c20a6cbd3571987db50b
#   Stored in directory: /root/.cache/pip/wheels/17/f2/18/43ed92f7192fb2a71175cf14e0397c98971795fe7d9d024829
#   Building wheel for user-agent (setup.py) ... done
#   Created wheel for user-agent: filename=user_agent-0.1.10-py3-none-any.whl size=18982 sha256=5bb7ef822338beee2bb0f108b1539cd744163e7e64388f03d104d81c0aba69e1
#   Stored in directory: /root/.cache/pip/wheels/09/a4/b8/8125d9fb731fb7c785eb41e8eda216297b1a9d4bb28a043397
# Successfully built grab pycurl weblib pytils selection user-agent
# Installing collected packages: user-agent, pytils, weblib, selection, pycurl, cssselect, pyquery, grab
# Successfully installed cssselect-1.1.0 grab-0.6.41 pycurl-7.43.0.1 pyquery-1.4.3 pytils-0.4.1 selection-0.0.14 user-agent-0.1.10 weblib-0.1.30

# %%
from grab import Grab
g = Grab()
resp = g.go('https://google.com')

from pyquery import PyQuery as pq
doc = pq(resp.body)
title = doc('title')
print(type(title), title.text())
# Out:
# <class 'pyquery.pyquery.PyQuery'> Google
