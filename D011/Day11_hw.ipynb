# %% [markdown]
# ## 作業說明
#
# Day11 我們介紹了 什麼是網路封包，並學習網站如何判斷需求的合法性
#
# 今日作業我們針對實際到網站上演練如何查看 Header 資訊
#
# 請依據下列題目需求進行截圖：

# %% [markdown]
# ### (1) 擷取 Headers
# - 站內搜尋結果頁面（送出查詢後的） [範例網頁](https://search.ltn.com.tw/list?keyword=%E5%B7%9D%E6%99%AE&start_time=20220109&end_time=20220110)
# - 打開「開發人員工具」，擷取其 Requests URL 的 Headers (General, Request Header, Response Header)

# %% [markdown]
# ![image.png](attachment:e0c914d6-67de-48b1-a519-87ff00c2a2a8.png)
# ![image.png](attachment:2f498ff3-9df7-43fb-9d70-d129cc4508c4.png)
# ![image.png](attachment:2e72f5f8-da89-4ae1-b3ba-3775b0256843.png)

# %% [markdown]
# ### (2) 擷取 Payload
# - 同 (1) 的網址，一樣在開發者工具找到 payload
# - 觀察他和 Request URL 的關聯

# %% [markdown]
# ![image.png](attachment:4fd7d3f0-58a3-485e-978e-a21be8583e18.png)
#
# Request URL: https://search.ltn.com.tw/list?keyword=%E6%8B%9C%E7%99%BB&start_time=20221101&end_time=20221102&type=all&sort=date
#
# url params<br>
# &emsp;&emsp;keyword: "%E6%8B%9C%E7%99%BB" （"拜登"一詞經過 url encoded）<br>
# &emsp;&emsp;start_time: 20220109<br>
# &emsp;&emsp;end_time: 20220110
