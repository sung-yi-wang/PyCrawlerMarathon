# %% [markdown]
# # Day29
# ## 動態網頁爬蟲起手式：Selenium
# - 認識 Selenium 及其應用
# - 瞭解 Selenium 如何用於動態爬蟲

# %% [markdown]
# ## 作業說明
# 練習使用 Selenium 爬取品類列表連結
# - 目標網站： https://channel.jd.com/outdoor.html
#
# 目標：
# - 取得當前所有小類別名稱
#
# ![](https://i.imgur.com/2aCtZM5.png)
#
# Hint:
# - 參考講義 Day29 內容
# - 請記得先安裝 Chrome 瀏覽器
# - 也會用到我們 Day20 所學的 Xpath

# %% [markdown]
# ### 套件導入

# %%
import time

import numpy as np
from fake_useragent import UserAgent
from selenium import webdriver
from selenium.webdriver.common.by import By
from tqdm import tqdm

# %% [markdown]
# ### 使用 fake-useragent 產生 User Agent

# %%
# 設定 user agent
opt = webdriver.ChromeOptions()
ua = UserAgent()
opt.add_argument(f'--user-agent={ua.random}')

# %% [markdown]
# ### 測試是否能成功啟動 webdriver 開啟目標網址

# %%
# 啟動 webdriver，載入目標網址
base_url = 'https://channel.jd.com/outdoor.html'

driver = webdriver.Remote(command_executor='http://selenium:4444/wd/hub', options=opt)
driver.maximize_window()
driver.get(base_url)
time.sleep(np.random.uniform(3, 5))

# %% [markdown]
# ### 獲取資料
# - 練習 selenium 操作
# - 活用 `WebElement.find_elements_by_xpath()`, `WebElement.text`, `WebElement.get_attribute()` 等方法

# %%
# 觀察有兩種規則
# 1. 大字類別： <div id="Categorys">...<dt>"戶外鞋服"</dt>   (網站本身英文複數用錯...)
# 2. 小字類別： <div id="Categorys">...<dd>...<a>"衝鋒衣褲"</a>

# 取得 <div id="Categorys"> 
categories = driver.find_element(By.XPATH, '//div[@id="Categorys"]')

# 取得所有 大字類別
# 使用相對路徑: "." 開頭
cate_names = []

for ele_group in tqdm(categories.find_elements(By.XPATH, './/dl[@class="item-inner"]')):
    medium_cate = ele_group.find_element(By.XPATH, './/dt').text
    for small_cate in ele_group.find_elements(By.XPATH, './/a'):
        cate_names.append((medium_cate, small_cate.text, small_cate.get_attribute('href')))
# Out:
# 100%|██████████| 5/5 [00:01<00:00,  3.54it/s]

# %%
driver.quit()

# %%
import pandas as pd

pd.DataFrame(cate_names, columns=["中類別","小類別","類別頁連結"])
# Out:
#      中類別     小類別                                              類別頁連結
# 0   户外鞋服    冲锋衣裤  https://list.jd.com/list.html?cat=1318%2C2628%...
# 1   户外鞋服     徒步鞋  https://list.jd.com/list.html?cat=1318%2C2628%...
# 2   户外鞋服    抓绒衣裤  https://list.jd.com/list.html?cat=1318,2628,12128
# 3   户外鞋服   羽绒服棉服  https://list.jd.com/list.html?cat=1318,2628,12126
# 4   户外鞋服    越野跑鞋  https://list.jd.com/list.html?cat=1318,2628,12137
# 5   户外鞋服      软壳  https://list.jd.com/list.html?cat=1318,2628,12129
# 6   户外鞋服     登山鞋  https://list.jd.com/list.html?cat=1318,2628,12134
# 7   户外鞋服     休闲鞋  https://list.jd.com/list.html?cat=1318,2628,12138
# 8   户外装备      帐篷   https://list.jd.com/list.html?cat=1318,1462,1473
# 9   户外装备      照明   https://list.jd.com/list.html?cat=1318,1462,1476
# 10  户外装备      背包   https://list.jd.com/list.html?cat=1318,1462,1472
# 11  户外装备    户外仪表   https://list.jd.com/list.html?cat=1318,1462,2631
# 12  户外装备      工具   https://list.jd.com/list.html?cat=1318,1462,1479
# 13  户外装备     望远镜   https://list.jd.com/list.html?cat=1318,1462,1480
# 14  户外装备    旅游用品   https://list.jd.com/list.html?cat=1318,1462,2691
# 15  户外装备    烧烤用具  https://list.jd.com/list.html?cat=1318,1462,13803
# 16  户外装备    野餐烧烤   https://list.jd.com/list.html?cat=1318,1462,1477
# 17  骑行运动     山地车  https://search.jd.com/Search?keyword=%E5%B1%B1...
# 18  骑行运动     电动车  https://search.jd.com/search?keyword=%E7%94%B5...
# 19  骑行运动   电动滑板车  https://search.jd.com/search?keyword=%E6%BB%91...
# 20  骑行运动  骑行穿戴装备  https://search.jd.com/Search?keyword=%E9%AA%91...
# 21  骑行运动     公路车  https://search.jd.com/Search?keyword=%E5%85%AC...
# 22  骑行运动     平衡车  https://search.jd.com/search?keyword=%E5%B9%B3...
# 23  骑行运动     折叠车  https://search.jd.com/Search?keyword=%E6%8A%98...
# 24    垂钓      鱼饵  https://list.jd.com/list.html?cat=1318,12147,1...
# 25    垂钓    鱼竿鱼线  https://list.jd.com/list.html?cat=1318,12147,1...
# 26    垂钓    钓鱼桌椅  https://list.jd.com/list.html?cat=1318,12147,1...
# 27    垂钓    浮漂鱼饵  https://list.jd.com/list.html?cat=1318,12147,1...
# 28    垂钓    钓鱼配件  https://list.jd.com/list.html?cat=1318,12147,1...
# 29    垂钓    钓鱼箱包  https://list.jd.com/list.html?cat=1318,12147,1...
# 30    游泳      泳镜  https://search.jd.com/Search?keyword=%E6%B3%B3...
# 31    游泳    女士泳衣  https://search.jd.com/Search?keyword=%E5%A5%B3...
# 32    游泳      泳裤  https://search.jd.com/Search?keyword=%E6%B3%B3...
# 33    游泳      泳帽  https://search.jd.com/Search?keyword=%E6%B3%B3...
# 34    游泳    冲浪潜水  https://search.jd.com/Search?keyword=%E5%86%B2...
# 35    游泳  游泳包防水包  https://list.jd.com/list.html?cat=1318,12154,1...
